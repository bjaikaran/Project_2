# %%
# !pip install msgpack-python
# Out:
# Requirement already satisfied: msgpack-python in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.4.8)
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (10.0.1)
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.

# %%
# !pip install pyprind
# Out:
#   Using cached https://files.pythonhosted.org/packages/1e/30/e76fb0c45da8aef49ea8d2a90d4e7a6877b45894c25f12fb961f009a891e/PyPrind-2.11.2-py3-none-any.whl
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.
# Installing collected packages: pyprind
# Successfully installed pyprind-2.11.2

# %%
# !pip install parser
# Out:
# Collecting parser
#   Could not find a version that satisfies the requirement parser (from versions: )
# No matching distribution found for parser

# %%
# !pip install statistics
# Out:
# Collecting statistics
#   Downloading https://files.pythonhosted.org/packages/bb/3a/ae99a15e65636559d936dd2159d75af1619491e8cb770859fbc8aa62cef6/statistics-1.0.3.5.tar.gz
# Requirement already satisfied: docutils>=0.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from statistics) (0.14)
# Building wheels for collected packages: statistics
#   Running setup.py bdist_wheel for statistics ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/75/55/90/73aa7662bfb4565b567618547a275f01372a678ca92ecd64f3
# Successfully built statistics
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.
# Installing collected packages: statistics
# Successfully installed statistics-1.0.3.5

# %%
# !pip install iexfinance
# Out:
# Collecting iexfinance
#   Downloading https://files.pythonhosted.org/packages/f0/d1/865dcc2efb7183fd0a9072f17214c39030ebda720e93d99ba76214c2f389/iexfinance-0.3.3.tar.gz
# Collecting pandas==0.21.0 (from iexfinance)
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/9b/b7/d829de9794567443fbe230a666910d2c5ea3c28a6554f1246ab004583b82/pandas-0.21.0-cp36-cp36m-manylinux1_x86_64.whl (26.2MB)
#     100% |████████████████████████████████| 26.2MB 22kB/s
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas==0.21.0->iexfinance) (2017.2)
# Requirement already satisfied: numpy>=1.9.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas==0.21.0->iexfinance) (1.14.5)
# Requirement already satisfied: python-dateutil>=2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas==0.21.0->iexfinance) (2.6.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests==2.18.4->iexfinance) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests==2.18.4->iexfinance) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests==2.18.4->iexfinance) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests==2.18.4->iexfinance) (2017.7.27.1)
# Requirement already satisfied: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil>=2->pandas==0.21.0->iexfinance) (1.11.0)
# Building wheels for collected packages: iexfinance
#   Running setup.py bdist_wheel for iexfinance ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/4a/db/46/67004f2b5fccd8a81edfc2f7a3ade2d568385cd0165b50739a
# Successfully built iexfinance
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.
# Installing collected packages: pandas, iexfinance
#   Found existing installation: pandas 0.20.3
#     Uninstalling pandas-0.20.3:
#       Successfully uninstalled pandas-0.20.3

# %%
# !pip install --upgrade pandas
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/57/eb/6ab533ea8e35e7dd159af6922ac1123d4565d89f3926ad9a6aa46530978f/pandas-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (11.8MB)
#     100% |████████████████████████████████| 11.8MB 490kB/s
# Requirement not upgraded as not directly required: numpy>=1.9.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (1.14.5)
# Requirement not upgraded as not directly required: python-dateutil>=2.5.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (2.6.1)
# Requirement not upgraded as not directly required: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas) (2017.2)
# Requirement not upgraded as not directly required: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
#       Successfully uninstalled pandas-0.21.0
# Successfully installed pandas-0.23.1

# %%
# !pip install json
# Out:
# Collecting json
#   Could not find a version that satisfies the requirement json (from versions: )
# No matching distribution found for json

# %%
# !pip freeze
# Out:
# adal==1.0.1
# alabaster==0.7.10
# altair==2.1.0
# anaconda-client==1.6.5
# anaconda-navigator==1.6.9
# anaconda-project==0.8.0
# applicationinsights==0.11.4
# argcomplete==1.9.4
# arrow==0.12.1
# asn1crypto==0.22.0
# astroid==1.5.3
# astropy==2.0.2
# attrs==18.1.0
# Automat==0.7.0
# azure-batch==4.1.3
# azure-batch-extensions==1.1.2
# azure-cli==2.0.37
# azure-cli-acr==2.0.26
# azure-cli-acs==2.1.0
# azure-cli-advisor==0.5.1
# azure-cli-ams==0.1.1
# azure-cli-appservice==0.1.34
# azure-cli-backup==1.1.1
# azure-cli-batch==3.2.3
# azure-cli-batchai==0.2.3
# azure-cli-billing==0.1.8
# azure-cli-cdn==0.0.14
# azure-cli-cloud==2.0.13
# azure-cli-cognitiveservices==0.1.13
# azure-cli-command-modules-nspkg==2.0.1
# azure-cli-configure==2.0.15
# azure-cli-consumption==0.3.1
# azure-cli-container==0.1.24
# azure-cli-core==2.0.37
# azure-cli-cosmosdb==0.1.21
# azure-cli-dla==0.1.0
# azure-cli-dls==0.0.21
# azure-cli-dms==0.0.1
# azure-cli-eventgrid==0.1.12
# azure-cli-eventhubs==0.1.3
# azure-cli-extension==0.0.14
# azure-cli-feedback==2.1.1
# azure-cli-find==0.2.9
# azure-cli-interactive==0.3.22
# azure-cli-iot==0.1.21
# azure-cli-keyvault==2.0.22
# azure-cli-lab==0.0.22
# azure-cli-monitor==0.1.7
# azure-cli-network==2.1.3
# azure-cli-nspkg==3.0.2
# azure-cli-profile==2.0.25
# azure-cli-rdbms==0.2.3
# azure-cli-redis==0.2.13
# azure-cli-reservations==0.1.2
# azure-cli-resource==2.0.30
# azure-cli-role==2.0.24
# azure-cli-servicebus==0.1.2
# azure-cli-servicefabric==0.0.12
# azure-cli-sql==2.0.27
# azure-cli-storage==2.0.34
# azure-cli-vm==2.0.33
# azure-common==1.1.12
# azure-datalake-store==0.0.19
# azure-graphrbac==0.40.0
# azure-keyvault==0.3.7
# azure-mgmt-advisor==1.0.1
# azure-mgmt-authorization==0.40.0
# azure-mgmt-batch==4.1.0
# azure-mgmt-batchai==1.0.0
# azure-mgmt-billing==0.2.0
# azure-mgmt-cdn==1.0.0
# azure-mgmt-cognitiveservices==1.0.0
# azure-mgmt-compute==4.0.0rc2
# azure-mgmt-consumption==2.0.0
# azure-mgmt-containerinstance==0.4.0
# azure-mgmt-containerregistry==2.0.0
# azure-mgmt-containerservice==4.0.0
# azure-mgmt-cosmosdb==0.4.0
# azure-mgmt-datalake-analytics==0.2.0
# azure-mgmt-datalake-nspkg==2.0.0
# azure-mgmt-datalake-store==0.2.0
# azure-mgmt-datamigration==0.1.0
# azure-mgmt-devtestlabs==2.0.0
# azure-mgmt-dns==2.0.0rc1
# azure-mgmt-eventgrid==0.4.0
# azure-mgmt-eventhub==1.2.0
# azure-mgmt-iothub==0.5.0
# azure-mgmt-iothubprovisioningservices==0.1.0
# azure-mgmt-keyvault==0.40.0
# azure-mgmt-managementgroups==0.1.0
# azure-mgmt-marketplaceordering==0.1.0
# azure-mgmt-media==1.0.0rc1
# azure-mgmt-monitor==0.5.0
# azure-mgmt-msi==0.1.0
# azure-mgmt-network==2.0.0rc2
# azure-mgmt-nspkg==2.0.0
# azure-mgmt-rdbms==1.1.0
# azure-mgmt-recoveryservices==0.1.0
# azure-mgmt-recoveryservicesbackup==0.1.1
# azure-mgmt-redis==4.1.0
# azure-mgmt-reservations==0.1.0
# azure-mgmt-resource==1.2.1
# azure-mgmt-servicebus==0.4.0
# azure-mgmt-servicefabric==0.1.0
# azure-mgmt-sql==0.9.1
# azure-mgmt-storage==1.5.0
# azure-mgmt-trafficmanager==0.40.0
# azure-mgmt-web==0.35.0
# azure-multiapi-storage==0.2.0
# azure-nspkg==2.0.0
# azure-storage-blob==1.1.0
# azure-storage-common==1.1.0
# azure-storage-nspkg==3.0.0
# azureml==0.2.7
# Babel==2.5.0
# backports.functools-lru-cache==1.4
# backports.shutil-get-terminal-size==1.0.0
# bcrypt==3.1.4
# beautifier==0.3.3
# beautifulsoup4==4.6.0
# bitarray==0.8.1
# bkcharts==0.2
# blaze==0.11.3
# bleach==2.0.0
# bokeh==0.12.7
# boto==2.48.0
# boto3==1.4.8
# botocore==1.8.50
# Bottleneck==1.2.1
# bqplot==0.10.5
# brewer2mpl==1.4.1
# CacheControl==0.12.3
# certifi==2017.7.27.1
# cffi==1.10.0
# chardet==3.0.4
# click==6.7
# cloudpickle==0.4.0
# clyent==1.2.2
# cntk==2.0
# colorama==0.3.9
# conda==4.5.4
# conda-build==3.0.27
# conda-verify==2.0.0
# constantly==15.1.0
# contextlib2==0.5.5
# cryptography==2.0.3
# cycler==0.10.0
# Cython==0.26.1
# cytoolz==0.8.2
# dask==0.15.3
# datacleaner==0.1.5
# datashape==0.5.4
# decorator==4.1.2
# distributed==1.19.1
# docker-py==1.10.6
# docker-pycreds==0.3.0
# docutils==0.14
# Dora==0.0.2
# edward==1.3.5
# elasticsearch==6.2.0
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# feedparser==5.2.1
# filelock==2.0.12
# Flask==0.12.2
# Flask-Cors==3.0.3
# ftfy==5.3.0
# future==0.16.0
# GDAL==2.2.4
# gevent==1.2.2
# ggplot==0.11.5
# glob2==0.5
# gmpy2==2.0.8
# graphviz==0.8.3
# greenlet==0.4.12
# grpcio==1.12.1
# gym==0.10.5
# h5py==2.7.1
# heapdict==1.0.0
# holoviews==1.8.3
# html5lib==0.999999999
# humanfriendly==4.12.1
# hyperlink==18.0.0
# idna==2.6
# iexfinance==0.3.3
# imageio==2.2.0
# imagesize==0.7.1
# incremental==17.5.0
# ipaddress==1.0.22
# ipykernel==4.7.0
# ipython==6.2.1
# ipython-genutils==0.2.0
# ipywidgets==7.0.0b7
# isodate==0.6.0
# isort==4.2.15
# itsdangerous==0.24
# jdcal==1.3
# jedi==0.10.2
# jeepney==0.3.1
# Jinja2==2.9.6
# jmespath==0.9.3
# joblib==0.11
# jsonschema==2.6.0
# jupyter-client==5.1.0
# jupyter-console==5.2.0
# jupyter-core==4.4.0
# jupyterlab==0.27.0
# jupyterlab-launcher==0.4.0
# kafka-python==1.4.3
# kazoo==2.5.0
# Keras==2.2.0
# Keras-Applications==1.0.2
# Keras-Preprocessing==1.0.1
# keyring==13.0.0
# klein==17.10.0
# knack==0.3.3
# lazy-object-proxy==1.3.1
# line-profiler==2.1.2
# llvmlite==0.20.0
# locket==0.2.0
# lockfile==0.12.2
# luigi==2.7.5
# lxml==4.1.0
# MarkupSafe==1.0
# matplotlib==2.1.1
# mccabe==0.6.1
# memory-profiler==0.52.0
# mistune==0.7.4
# mock==2.0.0
# mpmath==0.19
# msgpack-python==0.4.8
# msrest==0.5.0
# msrestazure==0.4.32
# multipledispatch==0.4.9
# natsort==5.1.0
# navigator-updater==0.1.0
# nbconvert==5.3.1
# nbformat==4.4.0
# networkx==1.11
# nltk==3.2.4
# nose==1.3.7
# notebook==5.0.0
# numba==0.35.0
# numexpr==2.6.2
# numpy==1.14.5
# numpydoc==0.7.0
# oauthlib==2.1.0
# odo==0.5.1
# olefile==0.44
# openfst==1.6.1
# openpyxl==2.4.8
# packaging==16.8
# pandas==0.23.1
# pandasql==0.7.3
# pandocfilters==1.4.2
# param==1.5.1
# paramiko==2.4.1
# partd==0.3.8
# path.py==10.3.1
# pathlib2==2.3.0
# patsy==0.4.1
# pbr==4.0.4
# pep8==1.7.0
# pexpect==4.2.1
# phonenumbers==8.9.8
# pickleshare==0.7.4
# Pillow==4.3.0
# pkginfo==1.4.1
# plotly==2.7.0
# ply==3.10
# prettypandas==0.0.4
# prompt-toolkit==1.0.15
# protobuf==3.4.1
# psutil==5.4.0
# psycopg2==2.7.1
# ptyprocess==0.5.2
# py==1.4.34
# pyang==1.7.5
# pyasn1==0.4.3
# pyasn1-modules==0.2.1
# pycodestyle==2.3.1
# pycosat==0.6.3
# pycparser==2.18
# pycrypto==2.6.1
# pycurl==7.43.0
# pydocumentdb==2.3.2
# pydot==1.2.4
# pyflakes==1.6.0
# PyGithub==1.39
# pyglet==1.3.2
# Pygments==2.2.0
# PyJWT==1.6.4
# pykafka==2.7.0
# pylint==1.7.4
# pymc==2.3.6
# pymc3==3.4.1
# pymongo==3.4.0
# Pympler==0.5
# pymssql==2.1.1
# PyMySQL==0.7.9
# PyNaCl==1.2.1
# pyodbc==3.1.1
# pyOpenSSL==17.2.0
# pypachy==0.1.5
# pyparsing==2.2.0
# PyPrind==2.11.2
# pyprof2calltree==1.4.3
# PySocks==1.6.7
# pytest==3.2.1
# python-daemon==2.1.2
# python-dateutil==2.6.1
# pytz==2017.2
# PyWavelets==0.5.2
# PyYAML==3.12
# pyzmq==16.0.2
# QtAwesome==0.4.4
# qtconsole==4.3.1
# QtPy==1.3.1
# readline==6.2.4.1
# requests==2.18.4
# requests-oauthlib==1.0.0
# rope==0.10.5
# rpy2==2.9.3
# ruamel-yaml==0.11.14
# s3transfer==0.1.13
# scikit-bio==0.5.1
# scikit-image==0.13.0
# scikit-learn==0.19.1
# scipy==0.19.1
# scp==0.11.0
# scrubadub==1.2.0
# seaborn==0.8
# SecretStorage==3.0.1
# service-identity==17.0.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# snakeviz==0.4.2
# snowballstemmer==1.2.1
# sortedcollections==0.5.3
# sortedcontainers==1.5.7
# Sphinx==1.6.3
# sphinxcontrib-websupport==1.0.1
# spyder==3.2.4
# SQLAlchemy==1.1.13
# sshtunnel==0.1.4
# statistics==1.0.3.5
# statsmodels==0.8.0
# sympy==1.1.1
# tables==3.4.2
# tabulate==0.8.2
# tblib==1.3.2
# tensorflow==1.1.0
# terminado==0.6
# testpath==0.3.1
# textblob==0.10.0
# Theano==1.0.2
# toolz==0.8.2
# torch==0.3.1.post2
# torchvision==0.1.9
# tornado==4.5.2
# tqdm==4.23.4
# traitlets==4.3.2
# traittypes==0.2.1
# treq==17.8.0
# Twisted==18.4.0
# typing==3.6.2
# unicodecsv==0.14.1
# update-checker==0.16
# urllib3==1.22
# vsts-cd-manager==1.0.2
# wcwidth==0.1.7
# webencodings==0.5.1
# websocket-client==0.48.0
# Werkzeug==0.12.2
# Whoosh==2.7.4
# widgetsnbextension==3.0.0
# word2vec==0.9.4
# wrapt==1.10.11
# xlrd==1.1.0
# XlsxWriter==1.0.2
# xlwt==1.3.0
# xmltodict==0.11.0
# zict==0.1.3
# zope.interface==4.5.0

# %%
# !pip install --upgrade SQLAlchemy
# Out:
# Collecting SQLAlchemy
#   Downloading https://files.pythonhosted.org/packages/b4/9c/411a9bac1a471bed54ec447dc183aeed12a75c1b648307e18b56e3829363/SQLAlchemy-1.2.8.tar.gz (5.6MB)
#     100% |████████████████████████████████| 5.6MB 1.1MB/s
#   Running setup.py bdist_wheel for SQLAlchemy ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/df/fc/61/df2f43ec3f11f864554bdc006a866a3ffffa59740bcf3674ef
# Successfully built SQLAlchemy
# iexfinance 0.3.3 has requirement pandas==0.21.0, but you'll have pandas 0.23.1 which is incompatible.
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.
# Installing collected packages: SQLAlchemy
#   Found existing installation: SQLAlchemy 1.1.13
#     Uninstalling SQLAlchemy-1.1.13:
#       Successfully uninstalled SQLAlchemy-1.1.13
# Successfully installed SQLAlchemy-1.2.8

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (3.4.0)
# iexfinance 0.3.3 has requirement pandas==0.21.0, but you'll have pandas 0.23.1 which is incompatible.
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (4.1.0)
# iexfinance 0.3.3 has requirement pandas==0.21.0, but you'll have pandas 0.23.1 which is incompatible.
# azure-datalake-store 0.0.19 has requirement msrest~=0.4.5, but you'll have msrest 0.5.0 which is incompatible.
