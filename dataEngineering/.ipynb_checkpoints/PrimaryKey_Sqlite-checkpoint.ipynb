# %%
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session

# %%
yahoo_df = pd.read_csv("yahoo.csv")
iex_df = pd.read_csv("iex.csv")
yahoo_df
# Out:
#            Date    Open    High     Low   Close      Volume Symbol  Source  \
# 0    2018-05-15   46.51   46.99   46.27   46.79   7,149,600     BP  Yahoo!
# 1    2018-05-15  249.48  249.58  246.25  247.34   1,638,200    FDX  Yahoo!
# 2    2018-05-15   54.58   54.75   53.56   53.92  21,712,600   INTC  Yahoo!
# 3    2018-05-15   97.24   97.85   96.34   97.32  24,594,000   MSFT  Yahoo!
# 4    2018-05-15   46.51   46.82   46.25   46.81  11,304,900   ORCL  Yahoo!
# 5    2018-05-15  115.78  116.47  114.85  115.61   3,480,400    UPS  Yahoo!
# 6    2018-05-15   81.85   82.03   81.40   81.79  12,595,700    XOM  Yahoo!
# 7    2018-05-16   46.80   46.82   46.43   46.71   4,866,500     BP  Yahoo!
# 8    2018-05-16  247.78  248.72  246.54  247.12   1,101,200    FDX  Yahoo!
# 9    2018-05-16   54.17   54.70   53.96   54.64  16,260,500   INTC  Yahoo!
# 10   2018-05-16   97.36   97.40   96.62   97.15  17,384,700   MSFT  Yahoo!
# 11   2018-05-16   46.93   46.93   46.45   46.73   9,874,200   ORCL  Yahoo!
# 12   2018-05-16  115.54  116.67  115.53  116.32   1,970,000    UPS  Yahoo!
# 13   2018-05-16   81.76   82.05   81.17   82.02   9,570,000    XOM  Yahoo!
# 14   2018-05-17   47.01   47.37   46.93   47.19   7,207,900     BP  Yahoo!
# 15   2018-05-17  247.69  250.23  247.28  248.46   1,084,000    FDX  Yahoo!
# 16   2018-05-17   54.55   55.44   54.42   54.81  16,872,600   INTC  Yahoo!
# 17   2018-05-17   96.76   97.54   95.83   96.18  17,246,700   MSFT  Yahoo!
# 18   2018-05-17   46.69   47.06   46.42   46.54  10,162,300   ORCL  Yahoo!
# 19   2018-05-17  116.59  117.44  116.40  116.59   3,697,200    UPS  Yahoo!
# 20   2018-05-17   82.20   82.28   81.44   81.88  11,224,100    XOM  Yahoo!
# 21   2018-05-18   47.30   47.44   47.14   47.38   4,276,600     BP  Yahoo!
# 22   2018-05-18  247.88  249.73  246.71  249.45   1,195,700    FDX  Yahoo!
# 23   2018-05-18   54.53   54.54   53.47   53.50  23,679,900   INTC  Yahoo!
# 24   2018-05-18   96.01   96.93   96.01   96.36  17,865,800   MSFT  Yahoo!
# 25   2018-05-18   46.69   46.79   46.24   46.32  13,517,300   ORCL  Yahoo!
# 26   2018-05-18  115.67  115.93  115.10  115.38   2,450,900    UPS  Yahoo!
# 27   2018-05-18   81.55   81.80   81.26   81.30  10,030,900    XOM  Yahoo!
# 28   2018-05-21   47.38   47.83   47.38   47.79   5,412,100     BP  Yahoo!
# 29   2018-05-21  251.00  254.94  250.68  254.66   1,384,200    FDX  Yahoo!
# ..          ...     ...     ...     ...     ...         ...    ...     ...
# 22   Coordination
# 23   Coordination
# 24   Coordination
# 25   Coordination
# 26   Coordination
# 27   Coordination
# 28   Coordination
# 29   Coordination
# ..            ...
# 180     Aftermath
# 181     Aftermath
# 182     Aftermath
# 183     Aftermath
# 184     Aftermath
# 185     Aftermath
# 186     Aftermath
# 187     Aftermath
# 188     Aftermath
# 189     Aftermath
# 190     Aftermath
# 191     Aftermath
# 192     Aftermath
# 193     Aftermath
# 194     Aftermath
# 195     Aftermath
# 196     Aftermath
# 197     Aftermath
# 198     Aftermath
# 199     Aftermath
# 200     Aftermath
# 201     Aftermath
# 202     Aftermath
# 203     Aftermath
# 204     Aftermath
# 205     Aftermath
# 206     Aftermath
# 207     Aftermath
# 208     Aftermath
# 209     Aftermath
#
# [210 rows x 9 columns]

# %%
class stocks(Base):
    __tablename__="stock_data"
    id = Column(Integer, primary_key=True)
    Date = Column(String)
    Open = Column(Float)
    High = Column(Float)
    Low = Column(Float)
    Close = Column(Float)
    Adj_Close = Column(Float)
    Volume = Column(Integer)
    Symbol = Column(String)
    Event = Column(String)

# %%
hashtag_df = pd.read_csv("Hashtags_combined.csv")
hashtag_df
# Out:
#             Hashtag  Count        Event
# 0              DPRK   3866       Summit
# 1               ROK   1636       Summit
# 2             Japan   1548       Summit
# 3    TrumpKimSummit    734       Summit
# 4   SingaporeSummit    690       Summit
# 5             China    360       Summit
# 6             Trump    330       Summit
# 7        NorthKorea    330       Summit
# 8              DPRK  19045  Rescheduled
# 9        NorthKorea   2794  Rescheduled
# 10         BREAKING   1130  Rescheduled
# 11            Trump    993  Rescheduled
# 12     AmericaFirst    515  Rescheduled
# 13    QuoteOfTheDay    475  Rescheduled
# 14           Lavrov    467  Rescheduled
# 15               US    397  Rescheduled

# %%
class hashtag(Base):
    __tablename__="hashtags"
    id = Column(Integer, primary_key=True)
    hashtag = Column(String)
    count = Column(Integer)
    event = Column(String)

# %%
engine = create_engine('sqlite:///stocks_hashtags_V1.sqlite', echo=False)
Base.metadata.create_all(engine)
session = Session(engine)

# %%
for index, row in stock_df.iterrows():
    print(row['Symbol'])
    session.add(stocks(Date = row['Date'], Open = row['Open'], High = row['High'], Low = row['Low'], Close = row['Close'], Adj_Close = row['Adj_Close'], Volume = row['Volume'], Symbol = row['Symbol'], Event = row['Event']))

for index, row in hashtag_df.iterrows():
    print(row['Hashtag'])
    session.add(hashtag(hashtag = row['Hashtag'], count = row['Count'], event = row['Event']))
# Out:
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# GSPC
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# EUXL
# DJA
# DJA
# DJA
# DJA
# DJA
# DJA
# DJA
# DJA
# DJA
# DJA
# DPRK
# ROK
# Japan
# TrumpKimSummit
# SingaporeSummit
# China
# Trump
# NorthKorea
# DPRK
# NorthKorea
# BREAKING
# Trump
# AmericaFirst
# QuoteOfTheDay
# Lavrov
# US

# %%
session.commit()
